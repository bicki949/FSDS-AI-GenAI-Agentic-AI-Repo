# %% [markdown]
# ## Tuple-Pyhton

# %%
t=()
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t1=(10,20,30,40,50,60,70)
print(t1)
# Out:
# (10, 20, 30, 40, 50, 60, 70)

# %%
t1.count(40)
# Out:
# 1

# %%
t1.count(30)
# Out:
# 1

# %%
t1.index(10)
# Out:
# 0

# %%
t1.index(40)
# Out:
# 3

# %%
t1[:]
# Out:
# (10, 20, 30, 40, 50, 60, 70)

# %%
t1[::]
# Out:
# (10, 20, 30, 40, 50, 60, 70)

# %%
t1[::2]
# Out:
# (10, 30, 50, 70)

# %%
t1.append(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 t1.append(20)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t1.insert(2,30)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 t1.insert(2,30)
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
t1
# Out:
# (10, 20, 30, 40, 50, 60, 70)

# %%
t1[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 t1[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
10 in t1
# Out:
# True

# %%
100 in t1
# Out:
# False

# %%
all(t1)
# Out:
# True

# %%
any(t1)
# Out:
# True

# %%
t1
# Out:
# (10, 20, 30, 40, 50, 60, 70)

# %%
t=[1,2,3,4,True,False]

# %%
type(t)
# Out:
# tuple

# %%
t
# Out:
# [1, 2, 3, 4, True, False]

# %%
len(t)
# Out:
# 6

# %%
5 in t
# Out:
# False

# %%
4 in t
# Out:
# True

# %%
all(t)
# Out:
# False

# %%
any(t)
# Out:
# True

# %%
t
# Out:
# [1, 2, 3, 4, True, False]

# %%
t[-1]
# Out:
# False

# %%
t
# Out:
# [1, 2, 3, 4, True, False]

# %%
t2=(10,2.3,True,'abhi',2+3j)#tuple mixed datatype
t2
# Out:
# (10, 2.3, True, 'abhi', (2+3j))

# %%
len(t2)
# Out:
# 5

# %%
t2
# Out:
# (10, 2.3, True, 'abhi', (2+3j))

# %%
t3=(20,1.2,{'Ram','lakshman'},[120,200])#Nested tuple

# %%
t3
# Out:
# (20, 1.2, {'Ram', 'lakshman'}, [120, 200])

# %%
len(t3)
# Out:
# 4

# %%
t4=(10,20,30,40)#tuple intiger numbers

# %%
t4
# Out:
# (10, 20, 30, 40)

# %%
t5=(1.2,3.4,5.6,7.8)#tuple float numbers

# %%
t5
# Out:
# (1.2, 3.4, 5.6, 7.8)

# %%
t6=(True,False)#tuple boolean numbers

# %%
t6
# Out:
# (True, False)

# %%
t7=(1+2j,2+3j,4+4j) #tuple coplex datatye

# %%
t7
# Out:
# ((1+2j), (2+3j), (4+4j))

# %% [markdown]
# # Tuple indexing

# %%
print(t)
print(t1)
print(t2)
print(t3)
print(t4)
print(t5)
print(t6)
print(t7)
# Out:
# [1, 2, 3, 4, True, False]
# (10, 20, 30, 40, 50, 60, 70)
# (10, 2.3, True, 'abhi', (2+3j))
# (20, 1.2, {'lakshman', 'Ram'}, [120, 200])
# (10, 20, 30, 40)
# (1.2, 3.4, 5.6, 7.8)
# (True, False)
# ((1+2j), (2+3j), (4+4j))

# %%
t.index(1)
# Out:
# 0

# %%
t.index(3)
# Out:
# 2

# %%
t1.index(30)
# Out:
# 3

# %%
t2.index((2+3j))
# Out:
# 4

# %%
t3.index({'lakshman','Ram'})
# Out:
# 2

# %%
t4.index(30)
# Out:
# 2

# %%
t5.index(5.6)
# Out:
# 2

# %%
t6.index(True)
# Out:
# 0

# %%
t7.index(1+2j)
# Out:
# 0

# %% [markdown]
# # Tuple Slicing

# %%
mytuple=('one','two','three','four','five','six','seven','eight','nine')

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine')

# %%
mytuple[0:3] #Return all items 0th to 3rd index location excluding
# Out:
# ('one', 'two', 'three')

# %%
mytuple[2:5]
# Out:
# ('three', 'four', 'five')

# %%
mytuple[:3]
# Out:
# ('one', 'two', 'three')

# %%
mytuple[:2]
# Out:
# ('one', 'two')

# %%
mytuple[-3:]
# Out:
# ('seven', 'eight', 'nine')

# %%
mytuple[-2:]
# Out:
# ('eight', 'nine')

# %%
mytuple[-1:]
# Out:
# ('nine',)

# %%
mytuple[:]
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine')

# %%
mytuple[::]
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine')

# %% [markdown]
# # Removing and change Items

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine')

# %%
del mytuple[0] #tuple immutable which means cannot DELETE tuple items
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 del mytuple[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
mytuple.clear()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 mytuple.clear()
#
# AttributeError: 'tuple' object has no attribute 'clear'

# %% [markdown]
# # Loop through Tuple

# %%
for i in mytuple:
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight
# nine

# %%
for i in enumerate(mytuple):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')
# (8, 'nine')

# %% [markdown]
# ## Nested-Loop

# %%
mytuple1=(1,2.3,('abhi','Ram','shyam','lakshman'),3+2J,(True,False,True))

# %%
mytuple1
# Out:
# (1, 2.3, ('abhi', 'Ram', 'shyam', 'lakshman'), (3+2j), (True, False, True))

# %%
len(mytuple1)
# Out:
# 5

# %%
mytuple1.index(3+2J)
# Out:
# 3

# %%
mytuple1.count(True)
# Out:
# 1

# %%
mytuple1.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 mytuple1.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
mytuple1.add('asish')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 mytuple1.add('asish')
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
mytuple1.remove(2.3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 mytuple1.remove(2.3)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
mytuple1
# Out:
# (1, 2.3, ('abhi', 'Ram', 'shyam', 'lakshman'), (3+2j), (True, False, True))

# %%
mytuple1[2]
# Out:
# ('abhi', 'Ram', 'shyam', 'lakshman')

# %% [markdown]
# ## Tuple Membership

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine')

# %%
'one' in mytuple
# Out:
# True

# %%
'ten' in myruple
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 'ten' in myruple
#
# NameError: name 'myruple' is not defined

# %%
'four' in mytuple
# Out:
# True

# %%
if 'three' in mytuple:
    print('Three is present in the Tuple')
else:
    print('Three is not present in tuple')
# Out:
# Three is present in the Tuple

# %%
if 'six' in mytuple:
    print('six is present in tuple')
else:
    print('six is not presemt in tuple')
# Out:
# six is present in tuple

# %% [markdown]
# ## index Position

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine')

# %%
mytuple.index('one')
# Out:
# 0

# %%
mytuple.index('six')#index of first elemrnt equal to five
# Out:
# 5

# %%
mytuple.index('nine')#index first element equal to nine
# Out:
# 8

# %%
mytuple.index('two')
# Out:
# 1

# %%
mytuple.index('one')
# Out:
# 0

# %% [markdown]
# ## Sorting

# %%
mytuple1=(20,40,56,18,40,38,50,28,40,70)
mytuple1
# Out:
# (20, 40, 56, 18, 40, 38, 50, 28, 40, 70)

# %%
sorted(mytuple1)#Return a new sortd List and doesnot change new orginal tuple
# Out:
# [18, 20, 28, 38, 40, 40, 40, 50, 56, 70]

# %%
sorted(mytuple1,reverse=True) #sort is decending order
# Out:
# [70, 56, 50, 40, 40, 40, 38, 28, 20, 18]
