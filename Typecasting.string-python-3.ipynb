# %% [markdown]
# Typecasting-Python-3

# %% [markdown]
# #Forward-indexing

# %%
s1='nareshittechnology'

# %%
s1
# Out:
# 'nareshittechnology'

# %%
len(s1)
# Out:
# 18

# %%
s1[:]
# Out:
# 'nareshittechnology'

# %%
s1[2:]
# Out:
# 'reshittechnology'

# %%
s1[:2]
# Out:
# 'na'

# %%
s1[6:]
# Out:
# 'ittechnology'

# %%
s1[:6]
# Out:
# 'naresh'

# %%
s1[1:15] #including 1...
# Out:
# 'areshittechnol'

# %%
s1[1:17]
# Out:
# 'areshittechnolog'

# %%
s1[1:17:4]
# Out:
# 'aheo'

# %% [markdown]
# # Backwars-indexing

# %%
s1='welcome'
s1
# Out:
# 'welcome'

# %%
s1[:]
# Out:
# 'welcome'

# %%
len(s1)
# Out:
# 7

# %%
s1[-1]
# Out:
# 'e'

# %%
s1[-4]
# Out:
# 'c'

# %%
s1[-5:-1]
# Out:
# 'lcom'

# %%
s2='datascience'

# %%
s2
# Out:
# 'datascience'

# %%
len(s2)
# Out:
# 11

# %%
s2[::1] #advance slicing
# Out:
# 'datascience'

# %%
s2[::2] #added to +2steps...
# Out:
# 'dtsine'

# %%
s2[::3]
# Out:
# 'daic'

# %%
s2[-3:-8:-4]
# Out:
# 'ns'

# %%
s2[-2:-5:-3]
# Out:
# 'c'

# %%
fruit='mango'

# %%
fruit
# Out:
# 'mango'

# %%
len(fruit)
# Out:
# 5

# %%
fruit[-3:-1]
# Out:
# 'ng'

# %%
fruit[:-3]
# Out:
# 'ma'

# %%
fruit[:-2:-4]
# Out:
# 'o'

# %%
fruit[-1:-2:-4]
# Out:
# 'o'

# %%
nm='Abhishek'

# %%
nm
# Out:
# 'Abhishek'

# %%
print(nm[-4:-2])
# Out:
# sh

# %%
nm
# Out:
# 'Abhishek'

# %%
nm[-3:-2:-4]
# Out:
# ''
