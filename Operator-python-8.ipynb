# %% [markdown]
# ## Working with Python-Operator

# %% [markdown]
# ## Arithmetic-Operator

# %%
x=15
y=24 
print(x+y)
# Out:
# 39

# %%
x=30
y=47 
print(x-y)
# Out:
# -17

# %%
x=20
y=10 
print(x*y)
# Out:
# 200

# %%
x=10
y=5
print(x/y)
# Out:
# 2.0

# %%
x=10
y=5
print(x//y)
# Out:
# 2

# %%
x=10
y=10
print(x**y)
# Out:
# 10000000000

# %% [markdown]
# ## Assignment Opeartor

# %%
a=20

# %%
a +=30

# %%
print(a)
# Out:
# 50

# %%
b=20
b+=10
print(b)
# Out:
# 30

# %%
a=40
print(a)
# Out:
# 40

# %%
a=40
a +=40
print(a)
# Out:
# 80

# %%
b=30
print(b)
# Out:
# 30

# %%
b-=10

# %%
b
# Out:
# 20

# %%
b=40
print(b)
# Out:
# 40

# %%
b-=20
print(b)
# Out:
# 20

# %%
b*=2
print(b)
# Out:
# 40

# %%
print(b)
# Out:
# 40

# %%
b*=6
print(b)
# Out:
# 240

# %%
b*=10
print(b)
# Out:
# 2400

# %%
b*=3
print(b)
# Out:
# 7200

# %%
b/=20
print(b)
# Out:
# 360.0

# %%
c=20
c/=3
print(c)
# Out:
# 6.666666666666667

# %%
c
# Out:
# 6.666666666666667

# %%
c/=3
print(c)
# Out:
# 2.2222222222222223

# %%
c=60
c//=15
print(c)
# Out:
# 4

# %%
c//=2
print(c)
# Out:
# 0

# %% [markdown]
# ## Unary Operator

# %%
n= 7 #negattion
n
# Out:
# 7

# %%
m= -n
print(m)
# Out:
# -7

# %%
a=-20
print(a)
# Out:
# -20

# %%
b= a
print(b)
# Out:
# -20

# %% [markdown]
# ## Relation operator (we are using for this for comparing)

# %%
x=39
y=49
print(x,y)
# Out:
# 39 49

# %%
print(x>y)
print(y<x)
# Out:
# False
# False

# %%
x>=y
# Out:
# False

# %%
y<=x
# Out:
# False

# %%
print(x==y)
print(x!=y)
# Out:
# False
# True

# %%
x=20
y=40
print(x>=y)
# Out:
# False

# %%
print(x<=y)
print(x>=y)
print(x==y)
print(x!=y)
# Out:
# True
# False
# False
# True

# %%
x=-39
y=20
print(x>=y)
# Out:
# False

# %%
print(x<=y)
print(x==y)
print(x!=y)
# Out:
# True
# False
# True

# %%
x=-20
y=-40
print(x>=y)
print(x<=y)
print(x==y)
print(x!=y)
print(x>y)
print(x<y)
# Out:
# True
# False
# False
# True
# True
# False

# %% [markdown]
# ## Logical Opeartor

# %%
y=20
z=30
print(y>9 and z<20)
# Out:
# False

# %%
y>29 and z<30
# Out:
# False

# %%
z>20 and y<39
# Out:
# True

# %%
y>2 or z>49
# Out:
# True

# %%
a=10
b=20
a>2 or b>39
# Out:
# True

# %%
a<20 or b>=20
# Out:
# True

# %%
a>3 or b<39
# Out:
# True

# %%
a!=b
# Out:
# True

# %%
a==b
# Out:
# False

# %%
b!=a
# Out:
# True

# %%
x==y
# Out:
# False

# %%
x!=y
# Out:
# True

# %%
y==x
# Out:
# False

# %%
x!=y
# Out:
# True

# %% [markdown]
# ## Print()

# %%
print(29)
print('sameer','ram')
print(1,3.4,'abhi',True,1+3J)
# Out:
# 29
# sameer ram
# 1 3.4 abhi True (1+3j)

# %%
num1=20
num2=39
add=num1+num2
print(add)
# Out:
# 59

# %%
a=20
b=20
sum=a+b
print(sum)
# Out:
# 40

# %% [markdown]
# ## Print result with string Format
# ## Use a print format method

# %%
value1=30
value2=30
add=value1+value2
print('The addition of {} and {} is equal to={}'.format(value1,value2,add))
# Out:
# The addition of 30 and 30 is equal to=60

# %%
value1=20
value2=30
value3=49
add=value1+value2+value3
print('The addition value of',value1,'and',value2,'or',value3,'total=',add)
# Out:
# The addition value of 20 and 30 or 49 total= 99

# %%
value1=20
value2=30
value3=49
add=value1*value2*value3
print('The Multiply value of{} and{}or{} is={}'.format(value1,value2,value3,add))
# Out:
# The Multiply value of20 and30or49 is=29400

# %%
value1=20
value2=30
value3=49
add=value1*value2*value3
print(f'The Multiply value of{value1}and{value2}or{value3}  is={add}')
# Out:
# The Multiply value of20and30or49  is=29400

# %%
pen=20
pencil=10
Eraser=5
Shapner=5
NooteBook=100
shoes=200
sum=pen+pencil+Eraser+Shapner+NooteBook+shoes
print('The  Student Instruments budgets are:  penprice$=',pen,'pencilprice$=',pencil,'Eraserprice$=',Eraser,'Shapnerprice$=',Shapner,'Nootebookprice$=',NooteBook,'shoesprice$=',shoes,'total budjet of=',sum)
# Out:
# The  Student Instruments budgets are:  penprice$= 20 pencilprice$= 10 Eraserprice$= 5 Shapnerprice$= 5 Nootebookprice$= 100 shoesprice$= 200 total budjet of= 340

# %%
pen=20
pencil=10
Eraser=5
Shapner=5
NooteBook=100
shoes=200
sum=pen+pencil+Eraser+Shapner+NooteBook+shoes
print('The student Instrument budjets are:penprice${} pnecilprice${} Eraserprice${} ShapnerPrice${} NooteBookprice${} shoesprice${} total budjet of={}'.format(pen,pencil,Eraser,Shapner,NooteBook,shoes,sum))
# Out:
# The student Instrument budjets are:penprice$20 pnecilprice$10 Eraserprice$5 ShapnerPrice$5 NooteBookprice$100 shoesprice$200 total budjet of=340

# %%
pen=20
pencil=10
Eraser=5
Shapner=5
NooteBook=100
shoes=200
add=pen+pencil+Eraser+Shapner+NooteBook+shoes
print(f'School instrument budjet are all students:pen${pen},pencil${pencil},Eraser${Eraser},Shapner${Shapner},NooteBook${NooteBook},Shoes${shoes} total budjet are={add}')
# Out:
# School instrument budjet are all students:pen$20,pencil$10,Eraser$5,Shapner$5,NooteBook$100,Shoes$200 total budjet are=340

# %%
apple=200
orange=250
greps=400
add=apple+orange+greps
print('A apple orange greps fruits budjets are:',apple,'and',orange,'or',greps,'of total Price of Fruits:',add)
# Out:
# A apple orange greps fruits budjets are: 200 and 250 or 400 of total Price of Fruits: 850

# %%
apple=200
orange=250
greps=400
add=apple+orange+greps
print('A apple orange greps fruits budjets are:{}and{}or{} of total Price of Fruits{}:'.format(apple,orange,greps,add))
# Out:
# A apple orange greps fruits budjets are:200and250or400 of total Price of Fruits850:

# %%
apple=200
orange=250
greps=400
add=apple+orange+greps
print(f'A apple orange greps fruits budjets are:{apple}and{orange}or{greps}of total Price of Fruits:{add}')
# Out:
# A apple orange greps fruits budjets are:200and250or400of total Price of Fruits:850

# %%
name='Abhishek sahoo'
age=20
location='Hydrabad'
Biodata=name,age,location
print(Biodata)
# Out:
# ('Abhishek sahoo', 20, 'Hydrabad')

# %%
print('My self {} and i am{}years old  from {}'.format(name,age,location,Biodata))
# Out:
# My self Abhishek sahoo and i am20years old  from Hydrabad

# %%
print(f'Hello i am {name} and i am {age} years old from {location}')
# Out:
# Hello i am Abhishek sahoo and i am 20 years old fromHydrabad

# %%
math=70
mil=90
eng=89
sce=90
average=math+mil+eng+sce/4
print('the average of all  subject math-',math,'mil-',mil,'eng-',eng,'sce-',sce,'is avg=',average)
print('The average of all subject math{} mil{} eng{} sce{} is avg{}'.format(math,mil,eng,sce,average))
print(f'the average of  subject are math{math},mil{mil},eng{eng},sce{sce} is average -{average}')
# Out:
# the average of all  subject math- 70 mil- 90 eng- 89 sce- 90 is avg= 271.5
# The average of all subject math70 mil90 eng89 sce90 is avg271.5
# the average of  subject are math70,mil90,eng89,sce90 is average -271.5

# %% [markdown]
# ## end statement

# %% [markdown]
# print('hello everyone')#first statement
# print('my self Abhishek')# second statement

# %%
print('hello everyone', end='') #Here we will use end statement that joint line from end of one string to starting of other string
print('my self Abhishek')
# Out:
# hello everyonemy self Abhishek

# %%
print('today is sunday',end='')# first statement
print('so today iam vey  excited',end='')# second statement
print('because today  is Holiday',end='')# third statement
# Out:
# today is sundayso today iam vey  excitedbecause today  is Holiday

# %% [markdown]
# ## seprator

# %% [markdown]
# # here we are use only print statement
# # we have use multiple value inside ine print statement
# # we want to seperate these multipal values with anything

# %%
print('hello','goodmorning','how are you', sep=',')
# Out:
# hello,goodmorning,how are you

# %%
print('hey','hii','have a nice day',sep='---')
# Out:
# hey---hii---have a nice day

# %%
print('price of fruits apple','orange','banana','greps','pineapple',sep=',')
# Out:
# price of fruits apple,orange,banana,greps,pineapple

# %%
print(2026, 10, 1, sep="-")
# Out:
# 2026-10-1

# %%
print("A", "B", "C", sep=" | ")
# Out:
# A | B | C

# %%
print('20','30','40','50',sep='+')
# Out:
# 20+30+40+50

# %%
a=30
b=49
c=49
print(a,b,c,sep='+')
# Out:
# 30+49+49

# %%
print('python','is','fun',sep='*')
# Out:
# python*is*fun

# %%
print(' red','green','blue',sep='\n')
# Out:
#  red
# green
# blue

# %%
print('red','green','blue',sep='\t')
# Out:
# red	green	blue

# %%
print('p','y','t','h','o','n',sep='')
# Out:
# python

# %%
print('*','*','*','*','*','*','*',sep='\n')
# Out:
# *
# *
# *
# *
# *
# *
# *

# %%
print(1,2,3,end='')# end statement
print(4,sep=',')# sep statement
# Out:
# 1 2 34

# %%
print(2,end='')
print(3,'.',end='')
print(4,'.') ## . is far from 4 so here we will use sep method
# Out:
# 23 .4 .

# %%
a = 5
b = 3
print(a, "+", b, "=", a + b, sep=" ")
# Out:
# 5 + 3 = 8

# %%
x=20
y=30
print(x, '-',y,'=',x-y,sep='')
# Out:
# 20-30=-10

# %%
x=20
y=7
print(x,'*',y,'=',x*y,sep='')
# Out:
# 20*7=140

# %%
print(x,'/',y,'=',x/y,sep='')
# Out:
# 20/7=2.857142857142857
