# %% [markdown]
# ## Operartors-Python

# %% [markdown]
# ## Arithmetic-Opearators

# %%
x=10
y=20
z=x+y
print(z)
# Out:
# 30

# %%
z
# Out:
# 30

# %%
x=10
y=10
z=x-y
print(z)
# Out:
# 0

# %%
z
# Out:
# 0

# %%
x=20
y=40
z=x*y
print(z)
# Out:
# 800

# %%
z
# Out:
# 800

# %%
x=20
y=30
z=x/y
print(z)
# Out:
# 0.6666666666666666

# %%
z
# Out:
# 0.6666666666666666

# %%
x=20
y=30
z=x%y
print(z)
# Out:
# 20

# %%
z
# Out:
# 20

# %%
x=20
y=30
z=x**y
print(z)
# Out:
# 1073741824000000000000000000000000000000

# %%
z
# Out:
# 1073741824000000000000000000000000000000

# %%
x=30
y=30
z=x//y
print(z)
# Out:
# 1

# %%
z
# Out:
# 1

# %% [markdown]
# ## Comparision-Operators

# %%
x=20
y=30
z=x>=y
print(z)
# Out:
# False

# %%
x=20
y=30
z=x<=y
print(z)
# Out:
# True

# %%
x=20
y=20
z=x!=y
print(z)
# Out:
# False

# %%
x=30
y=20
z=x>y
print(z)
# Out:
# True

# %%
x=30
y=50
z=x<y
print(z)
# Out:
# True

# %%
x=30
y=30
z=x==y
print(z)
# Out:
# True

# %%
x=30
y=20
z=x==y
print(z)
# Out:
# False

# %% [markdown]
# ## Assignment-Opereters

# %%
a=30
a=a+30 #a+=30 we arw assignment the value "a"
print(a)
# Out:
# 60

# %%
num=20
num=num-30 #num-= =>num=num-30    
print(num)
# Out:
# -10

# %%
num=30
num=num*30 #num*= =>num=num*30
print(num)
# Out:
# 900

# %%
num=30
num*=20
print("num:",num)
# Out:
# num: 600

# %%
num=49
num/=7
print("num:",num)
# Out:
# num: 7.0

# %%
num=10
num=num%5
print("num:",num)
# Out:
# num: 0

# %%
num=56
num/=7
print("num:",num)
# Out:
# num: 8.0

# %%
num=64
num**=8
print("num:",num)
# Out:
# num: 281474976710656

# %%
num=40
num//=4
print("num:",num)
# Out:
# num: 10

# %% [markdown]
# ## Logical-Opeareter

# %%
a=30
b=40
print(a>40 and b<30 )
# Out:
# False

# %%
a=29
b=30
print(a>b and a<b)
# Out:
# True

# %%
a=40
b=30
print(a>=b or a<=b)
# Out:
# True

# %%
print(a>b or a>b)
# Out:
# True

# %%
a=4
b=3
print(a>5 and b<10)
# Out:
# False

# %%
print(a<5 or b>9)
# Out:
# True

# %%
print( not a<10)
# Out:
# False

# %%
x=20
y=30
print( not y>25)
# Out:
# False

# %%
print(x>=30 and y<=37)
# Out:
# True

# %%
print(x<10 and y<20)
# Out:
# False

# %%
print(x>50 and x<40)
# Out:
# True

# %%
print(y>20 and x<30)
# Out:
# True

# %%
print(x>40 and y<35)
# Out:
# False

# %%
print(x<10 or y>40)
# Out:
# False

# %% [markdown]
# ## List-Membership

# %%
fruits=['apple','banana','orange','greps','cocanut']

# %%
fruits
# Out:
# ['apple', 'banana', 'orange', 'greps', 'cocanut']

# %%
'apple' in fruits
# Out:
# True

# %%
'banana' not in fruits
# Out:
# False

# %% [markdown]
# ## identity opearter

# %%
x=10
y=10

# %%
x
# Out:
# 10

# %%
y
# Out:
# 10

# %%
print(x is y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 print(x is y)
#
# TypeError: 'str' object is not callable

# %%
a=20
b=30
print(a,b)
# Out:
# 20 30

# %%
print(a is b)
# Out:
# False

# %%
type(a)
# Out:
# int

# %%
print(a is not b)
# Out:
# True

# %%
a=-10
b=40
print(a , b)
# Out:
# -10 40

# %%
print(a is b)
# Out:
# False

# %%
b=10
c=10
print(b is c)
# Out:
# True
