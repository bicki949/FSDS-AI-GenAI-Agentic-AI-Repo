# %% [markdown]
# DataType-Python-1

# %%
i=5

# %%
i
# Out:
# 5

# %%
type(i)
# Out:
# int

# %%
f=3.4

# %%
f
# Out:
# 3.4

# %%
type(f)
# Out:
# float

# %%
patrol=100.35

# %%
patrol
# Out:
# 100.35

# %%
type(patrol)
# Out:
# float

# %%
2e1 #here only allowed 'e'
# Out:
# 20.0

# %%
2e2
# Out:
# 200.0

# %%
2e3
# Out:
# 2000.0

# %%
3e3
# Out:
# 3000.0

# %%
8e3
# Out:
# 8000.0

# %%
a1=True

# %%
a1
# Out:
# True

# %%
type(a1)
# Out:
# bool

# %%
True+True
# Out:
# 2

# %%
True+False
# Out:
# 1

# %%
False-True
# Out:
# -1

# %%
True* True-False
# Out:
# 1

# %%
False/True
# Out:
# 0.0

# %%
True-False+True
# Out:
# 2

# %%
True+True
False-True
True-False*True
# Out:
# 1

# %%
print(True+True)
print(False-True)
print(True-False*True)
# Out:
# 2
# -1
# 1

# %%
# complex data types

# %%
c=10+3j

# %%
c
# Out:
# (10+3j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 3.0

# %%
type(c)
# Out:
# complex

# %%
c=10+2j
d=20+3j
e=c+d

# %%
e
# Out:
# (30+5j)

# %%
e.real
# Out:
# 30.0

# %%
e.imag
# Out:
# 5.0

# %% [markdown]
# #string data type

# %%
s1="Abhishek sahoo"

# %%
s1
# Out:
# 'Abhishek sahoo'

# %%
type(s1)
# Out:
# str

# %%
s1[0]
# Out:
# 'A'

# %%
s2='''hey i am use whatsapp
we can use this 
yes it acn'''

# %%
s2
# Out:
# 'hey i am use whatsapp\nwe can use this \nyes it acn'

# %%
s3="Virat Kohili"

# %%
s3
# Out:
# 'Virat Kohili'

# %%
s='welcome'

# %%
s
# Out:
# 'welcome'

# %%
s[0]
# Out:
# 'w'

# %%
s[-2]
# Out:
# 'm'

# %%
s[-4]
# Out:
# 'c'
