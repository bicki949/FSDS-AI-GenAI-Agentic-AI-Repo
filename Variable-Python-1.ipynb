# %% [markdown]
# Variable-python-1

# %%
v=5

# %%
v
# Out:
# 5

# %%
5=v
# Out:
#   Cell In[6], line 1
#     5=v
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
1v=10 variable should not use digit but end of the digit
# Out:
#   Cell In[7], line 1
#     1v=10
#     ^
# SyntaxError: invalid decimal literal

# %%
v1=20

# %%
v1
# Out:
# 20

# %%
nit=29 #case sensetive
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 nit=29
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit=20

# %%
nit
# Out:
# 20

# %%
v@=17 #special character are not allowed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 v@=17
#
# TypeError: unsupported operand type(s) for @=: 'int' and 'int'

# %%
v_ =40

# %%
v_
# Out:
# 40

# %%
nit_ @=60
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 nit_ @=60
#
# NameError: name 'nit_' is not defined

# %%
10/5
# Out:
# 2.0

# %%
10//5
# Out:
# 2

# %%
name="Abhishek"

# %%
name
# Out:
# 'Abhishek'

# %%
abhi_shek=23

# %%
abhi_shek
# Out:
# 23

# %%
3*2
# Out:
# 6

# %%
3**2
# Out:
# 9

# %%
age=34
print(age)
# Out:
# 34

# %%
price=20.000
print(price)
# Out:
# 20.0

# %%
x=10
print(x)
# Out:
# 10

# %%
x=10
y=10
print(x,y)
# Out:
# 10 10

# %%
id(x) # Addresss same why -because variable value be same.
# Out:
# 140734960608456

# %%
id(y)
# Out:
# 140734960608456

# %%
x=20

# %%
x
# Out:
# 20

# %%
id(x) #address are not same bracause -because value be not same
# Out:
# 140734960608776

# %%
y=29

# %%
y
# Out:
# 29

# %%
id(y)
# Out:
# 140734960609064

# %%
first_name="john"
last_name="Doe"
full_name=first_name+ " "+last_name
print(full_name)
# Out:
# john Doe

# %%
length=10
width=5
area=length * width
print(area)
# Out:
# 50

# %%
x=10
print(x)
# Out:
# 10
